# %% [markdown]
# <a href="https://colab.research.google.com/github/RobSouzaUFPE/ScriptPython/blob/main/Primeirospassos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.plotting.register_matplotlib_converters()

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
print("Setup Complete")
# Out:
# Setup Complete

# %%
pd.read_csv('WorldCupPlayers.csv')
# Out:
#        RoundID    MatchID Team Initials               Coach Name Line-up  \
# 0          201       1096           FRA      CAUDRON Raoul (FRA)       S
# 1          201       1096           MEX         LUQUE Juan (MEX)       S
# 2          201       1096           FRA      CAUDRON Raoul (FRA)       S
# 3          201       1096           MEX         LUQUE Juan (MEX)       S
# 4          201       1096           FRA      CAUDRON Raoul (FRA)       S
# ...        ...        ...           ...                      ...     ...
# 37779   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
# 37780   255959  300186501           GER       LOEW Joachim (GER)       N
# 37781   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
# 37782   255959  300186501           GER       LOEW Joachim (GER)       N
# 37783   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
#
#        Shirt Number       Player Name Position       Event
# ...

# %%
fifa_filepath = "WorldCupPlayers.csv"

# %%
fifa_data = pd.read_csv(fifa_filepath, index_col="Team Initials", parse_dates=True)

# %%
fifa_data.head()
# Out:
#                RoundID  MatchID           Coach Name Line-up  Shirt Number  \
# Team Initials
# FRA                201     1096  CAUDRON Raoul (FRA)       S             0
# MEX                201     1096     LUQUE Juan (MEX)       S             0
# FRA                201     1096  CAUDRON Raoul (FRA)       S             0
# MEX                201     1096     LUQUE Juan (MEX)       S             0
# FRA                201     1096  CAUDRON Raoul (FRA)       S             0
#
#                     Player Name Position Event
# Team Initials
# FRA                 Alex THEPOT       GK   NaN
# MEX             Oscar BONFIGLIO       GK   NaN
# FRA            Marcel LANGILLER      NaN  G40'
# MEX                Juan CARRENO      NaN  G70'
# FRA             Ernest LIBERATI      NaN   NaN
